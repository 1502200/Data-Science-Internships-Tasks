# %% [markdown]
# # Task_1 - Iris Flower Classification

# %% [markdown]
# ## Name- Aishwarya Nandkumar Sorate

# %%
import pandas as pd 
import numpy as np 
import seaborn as sn

# %%
data=pd.read_csv("Iris.csv")
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %%
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
data.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
data.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
data.shape
# Out:
# (150, 6)

# %%
data.groupby('Species').mean()
# Out:
#                     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Species
# Iris-setosa       25.5          5.006         3.418          1.464
# Iris-versicolor   75.5          5.936         2.770          4.260
# Iris-virginica   125.5          6.588         2.974          5.552
#
#                  PetalWidthCm
# Species
# Iris-setosa             0.244
# Iris-versicolor         1.326
# Iris-virginica          2.026

# %% [markdown]
# ## Data Visualization

# %%
import matplotlib.pyplot as plt
sns.scatterplot(x='SepalLengthCm', y='SepalWidthCm', hue='Species', data=data)
plt.show()

# %%
sns.lineplot(data=data.drop(['Species'], axis=1))
plt.show()

# %%
sns.heatmap(data.corr(), annot=True)
plt.show()

# %%
g = sns.FacetGrid(data, col='Species')
g = g.map(sns.kdeplot, 'SepalLengthCm')

# %%
sns.pairplot(data)

# %%
data.hist(color= 'mediumpurple' ,edgecolor='black',figsize=(10,10))
plt.show()

# %%
data.corr().style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# C:\Users\ghj\AppData\Local\Temp\ipykernel_1420\286891049.py:1: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   data.corr().style.background_gradient(cmap='coolwarm').set_precision(2)
# <style type="text/css">
# #T_40959_row0_col0, #T_40959_row1_col1, #T_40959_row2_col2, #T_40959_row3_col3, #T_40959_row4_col4 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_40959_row0_col1 {
#   background-color: #f59c7d;
#   color: #000000;
# }
# #T_40959_row0_col2 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_40959_row0_col3, #T_40959_row3_col0 {
#   background-color: #d1493f;
#   color: #f1f1f1;
# }
# #T_40959_row0_col4, #T_40959_row4_col0 {
#   background-color: #cd423b;
#   color: #f1f1f1;
# }
# #T_40959_row1_col0 {
#   background-color: #ee8468;
#   color: #f1f1f1;
# }
# #T_40959_row1_col2 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_40959_row1_col3 {
#   background-color: #d44e41;
#   color: #f1f1f1;
# }
# #T_40959_row1_col4 {
#   background-color: #e0654f;
#   color: #f1f1f1;
# }
# #T_40959_row2_col0, #T_40959_row2_col1, #T_40959_row2_col3, #T_40959_row2_col4, #T_40959_row3_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_40959_row3_col1 {
#   background-color: #da5a49;
#   color: #f1f1f1;
# }
# #T_40959_row3_col4 {
#   background-color: #be242e;
#   color: #f1f1f1;
# }
# #T_40959_row4_col1 {
#   background-color: #e7745b;
#   color: #f1f1f1;
# }
# #T_40959_row4_col2 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_40959_row4_col3 {
#   background-color: #bd1f2d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_40959">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_40959_level0_col0" class="col_heading level0 col0" >Id</th>
#       <th id="T_40959_level0_col1" class="col_heading level0 col1" >SepalLengthCm</th>
#       <th id="T_40959_level0_col2" class="col_heading level0 col2" >SepalWidthCm</th>
#       <th id="T_40959_level0_col3" class="col_heading level0 col3" >PetalLengthCm</th>
#       <th id="T_40959_level0_col4" class="col_heading level0 col4" >PetalWidthCm</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_40959_level0_row0" class="row_heading level0 row0" >Id</th>
#       <td id="T_40959_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_40959_row0_col1" class="data row0 col1" >0.72</td>
#       <td id="T_40959_row0_col2" class="data row0 col2" >-0.40</td>
#       <td id="T_40959_row0_col3" class="data row0 col3" >0.88</td>
#       <td id="T_40959_row0_col4" class="data row0 col4" >0.90</td>
#     </tr>
#     <tr>
#       <th id="T_40959_level0_row1" class="row_heading level0 row1" >SepalLengthCm</th>
#       <td id="T_40959_row1_col0" class="data row1 col0" >0.72</td>
#       <td id="T_40959_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_40959_row1_col2" class="data row1 col2" >-0.11</td>
#       <td id="T_40959_row1_col3" class="data row1 col3" >0.87</td>
#       <td id="T_40959_row1_col4" class="data row1 col4" >0.82</td>
#     </tr>
#     <tr>
#       <th id="T_40959_level0_row2" class="row_heading level0 row2" >SepalWidthCm</th>
#       <td id="T_40959_row2_col0" class="data row2 col0" >-0.40</td>
#       <td id="T_40959_row2_col1" class="data row2 col1" >-0.11</td>
#       <td id="T_40959_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_40959_row2_col3" class="data row2 col3" >-0.42</td>
#       <td id="T_40959_row2_col4" class="data row2 col4" >-0.36</td>
#     </tr>
#     <tr>
#       <th id="T_40959_level0_row3" class="row_heading level0 row3" >PetalLengthCm</th>
#       <td id="T_40959_row3_col0" class="data row3 col0" >0.88</td>
#       <td id="T_40959_row3_col1" class="data row3 col1" >0.87</td>
#       <td id="T_40959_row3_col2" class="data row3 col2" >-0.42</td>
#       <td id="T_40959_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_40959_row3_col4" class="data row3 col4" >0.96</td>
#     </tr>
#     <tr>
#       <th id="T_40959_level0_row4" class="row_heading level0 row4" >PetalWidthCm</th>
#       <td id="T_40959_row4_col0" class="data row4 col0" >0.90</td>
#       <td id="T_40959_row4_col1" class="data row4 col1" >0.82</td>
#       <td id="T_40959_row4_col2" class="data row4 col2" >-0.36</td>
#       <td id="T_40959_row4_col3" class="data row4 col3" >0.96</td>
#       <td id="T_40959_row4_col4" class="data row4 col4" >1.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Machine Learning

# %%
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import accuracy_score

# %%
x = data.drop('Species', axis=1)
y= data.Species

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.4, random_state=5)

# %% [markdown]
# ## SVM

# %%
from sklearn.svm import SVC
svm = SVC(kernel='rbf', random_state=0, gamma=.10, C=1.0)
svm.fit(x_train, y_train)

svm.score(x_test, y_test)
# Out:
# 1.0
